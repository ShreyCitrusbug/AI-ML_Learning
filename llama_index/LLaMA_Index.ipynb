# %% [markdown]
# Anthropic

# %% [markdown]
# Set Tokenizer

# %%
import os
import anthropic
from llama_index.llms.anthropic import Anthropic
from llama_index.core import settings

# %%
client = anthropic.Anthropic()

# %%
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")

# %%
llm = Anthropic(model="claude-3-opus-20240229")

# %%
resp = llm.complete("Paul Graham is ")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 resp = llm.complete("Paul Graham is ")
#
# File c:\Citrusbug-Project\AI-ML_Learning\venv_AI\lib\site-packages\llama_index\core\llms\callbacks.py:343, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     326 dispatcher.event(
#     327     LLMCompletionStartEvent(
#     328         model_dict=model_dict,
#    (...)
#     332     )
#     333 )
#     334 event_id = callback_manager.on_event_start(
#     335     CBEventType.LLM,
#     336     payload={
#    (...)
#     340     },
#     341 )
# --> 343 f_return_val = f(_self, *args, **kwargs)
#     344 if isinstance(f_return_val, Generator):
#     345     # intercept the generator and add a callback to the end
#     346     def wrapped_gen() -> CompletionResponseGen:
#
# ...

# %% [markdown]
# Load data and build an index

# %%
import os
import openai

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, TreeIndex

openai.api_key = os.getenv("OPEN_API_KEY")

# %%
# document = SimpleDirectoryReader("data").load_data()
# index = VectorStoreIndex.from_documents(documents=document)
resume = SimpleDirectoryReader("pdf").load_data()
new_index = TreeIndex.from_documents(resume)

# %%
new_index

# %% [markdown]
# Query your data

# %%
query_engine = new_index.as_query_engine()
response = query_engine.query("When did Abid graduated?")
print(response)
# Out:
# Retrying llama_index.llms.openai.base.OpenAI._chat in 0.32474027497328806 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# Retrying llama_index.llms.openai.base.OpenAI._chat in 0.3878047714410908 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}.
# ...
