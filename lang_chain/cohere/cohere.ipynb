# %% [markdown]
# Setup

# %% [markdown]
# set the COHERE_API_KEY environment variable

# %%
import os

# %%
os.environ["COHERE_API_KEY"] = os.getenv("COHERE_API_KEY")
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANG_CHAIN_API_KEY")

# %% [markdown]
# Usage

# %%
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage, SystemMessage

LANGCHAIN_TRACING_V2 = bool(os.getenv("LANGCHAIN_TRACING_V2"))

# %%
chat = ChatCohere(model="command")

# %%
messages = [HumanMessage(content="Hi!!")]
print(chat.invoke(messages))
# Out:
# content="Hey there! I'm your friendly AI-assistant chatbot, and I'm here to help you with whatever you need. Just let me know if there's anything I can do to assist you, and I'll do my best to provide helpful and thorough responses. \n\nSo, how can I help you today?" additional_kwargs={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': '676e30ae-1f52-4dc7-9f88-150737ae4430', 'token_count': {'input_tokens': 64, 'output_tokens': 63}} response_metadata={'documents': None, 'citations': None, 'search_results': None, 'search_queries': None, 'is_search_required': None, 'generation_id': '676e30ae-1f52-4dc7-9f88-150737ae4430', 'token_count': {'input_tokens': 64, 'output_tokens': 63}} id='run-7e4e2ab9-04a5-4b98-8d83-870c3e907f14-0'

# %% [markdown]
# [Legacy] __call__

# %%
chat(
    [
        HumanMessage(
            content="Translate this sentence from English to French: I love programming."
        )
    ]
)
# Out:
# c:\Citrusbug-Project\AI-ML_Learning\venv_AI\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ...

# %% [markdown]
# LLM

# %%
from langchain_cohere.llms import Cohere

# %%
llm = Cohere()

# %%
print(llm.invoke("Come up with a pet name"))
# Out:
#  Of course! Here are a few suggestions for pet names:
#
# - Honeybear
# - Babygirl
# - Sweetheart
# - Doll
# - Cutiepie
# - Snugglebug
#
# These are just suggestions, and you may want to choose a pet name that has a special meaning for you and your loved one.
#
# I can provide you with some tips on how to choose the perfect pet name if you would like!

# %% [markdown]
# RAG Retriever

# %%
from langchain_cohere import CohereRagRetriever
from langchain_core.documents import Document

rag = CohereRagRetriever(llm=ChatCohere())

# %%
print(rag)
# Out:
# llm=ChatCohere(client=<cohere.client.Client object at 0x0000025CAA7C9D00>, async_client=<cohere.client.AsyncClient object at 0x0000025CAA7C9CD0>, cohere_api_key=SecretStr('**********'))

# %% [markdown]
# Text Embedding

# %%
from langchain_cohere import CohereEmbeddings

embed = CohereEmbeddings() 
print(embed.embed_documents(['This is test']))
# Out:
# [[1.8720703, 0.7441406, 1.2255859, -0.34301758, 1.1728516, 0.19628906, -1.7939453, -1.6708984, -0.072753906, 2.0683594, -0.010093689, -0.68359375, -0.5151367, -0.68359375, 0.7426758, -0.9584961, 1.5166016, 1.9560547, 1.2441406, -2.2011719, 0.15893555, -0.09893799, 2.0683594, 3.03125, 2.078125, -0.3227539, 2.0234375, -0.05923462, -0.3984375, -0.8125, 1.296875, -0.328125, 0.39453125, 0.6098633, 1.9453125, 1.0214844, 2.6855469, -0.8276367, 2.4882812, 0.2919922, -0.18713379, 0.012535095, 0.39282227, -0.41601562, 1.2324219, -1.7373047, -0.05392456, 1.7841797, 1.1884766, 0.17919922, 0.96240234, 0.4260254, -1.1728516, 0.24072266, 0.08935547, -1.2509766, -3.8964844, -1.9658203, 2.5292969, -1.5244141, -0.71875, 2.8261719, -0.43945312, 0.31079102, 1.3359375, 1.2802734, -1.2773438, -2.671875, -0.40429688, 1.2929688, -3.1113281, 0.77685547, -0.072265625, -0.6801758, -0.09246826, 1.453125, -1.5966797, -1.6572266, 1.0888672, 0.3215332, 0.08538818, 0.1282959, 1.4443359, 0.05923462, -0.43823242, -0.
# ...

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.cohere import Cohere
cohere_obj = Cohere(api_key=os.getenv("COHERE_API_KEY"))

# %%
message = ChatMessage(role='user',content="Who founded google?")
res = cohere_obj.chat([message])
print(res)
# Out:
# assistant: Google was founded by Larry Page and Sergey Brin on September 4, 1998. The two founders met at Stanford University, where they collaborated on a research project on large-scale information retrieval. Page and Brin envisioned a search engine that could organize and make sense of the vast amount of information available on the internet, and thus Google was born. They wanted to develop a system that would give more accurate search results by analyzing the links between websites.
#
# The company has grown exponentially since its inception and has expanded its offerings beyond just a search engine. Google's early innovations in search technology and its mission to organize the world's information have made it a household name and a tech industry leader. Larry Page and Sergey Brin served as CEOs and key figures in the company for many years, but have since stepped down from their roles. Today, Sundar Pichai is the CEO of Google and its parent company Alphabet Inc.
